# %%
import yfinance as yf
msft = yf.Ticker("MSFT")
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
# get stock info</em>
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
# get historical market data</em> 
hmd=msft.history(period="max") print(hmd)
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-01-23  166.19  166.80  165.27  166.72    19680800        0.0
# 2020-01-24  167.51  167.53  164.45  165.04    24918100        0.0
# 2020-01-27  161.15  163.38  160.20  162.28    32078100        0.0
# 2020-01-28  163.78  165.76  163.07  165.46    24819800        0.0
# 2020-01-29  167.84  168.00  165.70  167.65    13725851        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
# show actions (dividends, splits)</em> 
msft.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1987-09-21       0.00           2.0
# 1990-04-16       0.00           2.0
# 1991-06-27       0.00           1.5
# 1992-06-15       0.00           1.5
# 1994-05-23       0.00           2.0
# ...               ...           ...
# 2018-11-14       0.46           0.0
# 2019-02-20       0.46           0.0
# 2019-05-15       0.46           0.0
# 2019-08-14       0.46           0.0
# 2019-11-20       0.51           0.0
#
# [73 rows x 2 columns]

# %%
# show dividends</em> 
msft.dividends
# Out:
# Date
# 2003-02-19    0.08
# 2003-10-15    0.16
# 2004-08-23    0.08
# 2004-11-15    3.08
# 2005-02-15    0.08
#               ...
# 2018-11-14    0.46
# 2019-02-20    0.46
# 2019-05-15    0.46
# 2019-08-14    0.46
# 2019-11-20    0.51
# Name: Dividends, Length: 64, dtype: float64

# %%
# show splits</em> 
msft.splits
# Out:
# Date
# 1987-09-21    2.0
# 1990-04-16    2.0
# 1991-06-27    1.5
# 1992-06-15    1.5
# 1994-05-23    2.0
# 1996-12-09    2.0
# 1998-02-23    2.0
# 1999-03-29    2.0
# 2003-02-18    2.0
# Name: Stock Splits, dtype: float64
